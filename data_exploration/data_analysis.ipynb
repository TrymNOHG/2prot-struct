# %%
import pandas as pd
import numpy as np
from scipy.stats import entropy
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")

# %%
total_sum = 0

for i in range(39, 201):
    count = (data["input"].apply(len) <= i).sum()
    total_sum += count
    print(f"Count for i <= {i}: {count}")

print(f"Total sum: {total_sum + 1}")
# Out:
# Count for i <= 39: 2
# Count for i <= 40: 50
# Count for i <= 41: 85
# Count for i <= 42: 127
# Count for i <= 43: 165
# Count for i <= 44: 201
# Count for i <= 45: 238
# Count for i <= 46: 285
# Count for i <= 47: 334
# Count for i <= 48: 368
# Count for i <= 49: 401
# Count for i <= 50: 438
# Count for i <= 51: 468
# Count for i <= 52: 512
# Count for i <= 53: 562
# Count for i <= 54: 596
# Count for i <= 55: 639
# Count for i <= 56: 700
# Count for i <= 57: 765
# Count for i <= 58: 815
# Count for i <= 59: 868
# Count for i <= 60: 939
# Count for i <= 61: 1000
# Count for i <= 62: 1069
# Count for i <= 63: 1126
# Count for i <= 64: 1189
# Count for i <= 65: 1258
# Count for i <= 66: 1329
# Count for i <= 67: 1393
# Count for i <= 68: 1459
# Count for i <= 69: 1510
# Count for i <= 70: 1584
# Count for i <= 71: 1652
# Count for i <= 72: 1713
# Count for i <= 73: 1778
# Count for i <= 74: 1862
# Count for i <= 75: 1940
# Count for i <= 76: 2000
# Count for i <= 77: 2067
# ...

# %%
sequences = data["input"]
len(sequences)
# Out:
# 18731

# %%
sequence_lengths = data["input"].apply(len)

mean_length = np.mean(sequence_lengths)
median_length = np.median(sequence_lengths)
max_length = np.max(sequence_lengths)

print(f"Mean length: {mean_length}")
print(f"Median length: {median_length}")
print(f"Maximum length: {max_length}")
# Out:
# Mean length: 213.95841119000588
# Median length: 172.0
# Maximum length: 1723

# %%
percentile_70 = np.percentile(sequence_lengths, 70)
percentile_75 = np.percentile(sequence_lengths, 75)
percentile_80 = np.percentile(sequence_lengths, 80)
percentile_85 = np.percentile(sequence_lengths, 85)
percentile_90 = np.percentile(sequence_lengths, 90)
percentile_95 = np.percentile(sequence_lengths, 95)


print(f"70th percentile: {percentile_70}")
print(f"75th percentile: {percentile_75}")
print(f"80th percentile: {percentile_80}")
print(f"85th percentile: {percentile_85}")
print(f"90th percentile: {percentile_90}")
print(f"95th percentile: {percentile_95}")
# Out:
# 70th percentile: 259.0
# 75th percentile: 286.0
# 80th percentile: 316.0
# 85th percentile: 351.0
# 90th percentile: 401.0
# 95th percentile: 487.0

# %%
median = np.median([259,286,316,351,401,487])
median
# Out:
# 333.5

# %%
plt.figure(figsize=(10, 5))
sns.histplot(sequence_lengths, bins=50, kde=True)
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
plt.title("Distribution of Sequence Lengths")
plt.show()

# Boxplot to identify outliers
plt.figure(figsize=(8, 4))
sns.boxplot(x=sequence_lengths)
plt.title("Boxplot of Sequence Lengths")
plt.show()

# %%
# Count occurrences of each sequence length
length_counts = data["dssp8"].apply(len).value_counts().sort_index()

# Print the counts
for length, count in length_counts.items():
    print(f"Length: {length}, Count: {count}")
plt.figure(figsize=(10, 5))
sns.barplot(x=length_counts.index, y=length_counts.values, palette="viridis")
plt.xlabel("Sequence Length")
plt.ylabel("Count")
plt.title("Distribution of Sequence Lengths")
plt.xticks(rotation=90)  # Rotate labels for better readability if needed
plt.show()
# Out:
# Length: 39, Count: 2
# Length: 40, Count: 48
# Length: 41, Count: 35
# Length: 42, Count: 42
# Length: 43, Count: 38
# Length: 44, Count: 36
# Length: 45, Count: 37
# Length: 46, Count: 47
# Length: 47, Count: 49
# Length: 48, Count: 34
# Length: 49, Count: 33
# Length: 50, Count: 37
# Length: 51, Count: 30
# Length: 52, Count: 44
# Length: 53, Count: 50
# Length: 54, Count: 34
# Length: 55, Count: 43
# Length: 56, Count: 61
# Length: 57, Count: 65
# Length: 58, Count: 50
# Length: 59, Count: 53
# Length: 60, Count: 71
# Length: 61, Count: 61
# Length: 62, Count: 69
# Length: 63, Count: 57
# Length: 64, Count: 63
# Length: 65, Count: 69
# Length: 66, Count: 71
# Length: 67, Count: 64
# Length: 68, Count: 66
# Length: 69, Count: 51
# Length: 70, Count: 74
# Length: 71, Count: 68
# Length: 72, Count: 61
# Length: 73, Count: 65
# Length: 74, Count: 84
# Length: 75, Count: 78
# Length: 76, Count: 60
# Length: 77, Count: 67
# Length: 78, Count: 63
# Length: 79, Count: 77
# ...

# %%
for seq in data["input"].head(10):
    print(f"Length: {len(seq)}")
# Out:
# Length: 361
# Length: 457
# Length: 127
# Length: 503
# Length: 214
# Length: 152
# Length: 285
# Length: 209
# Length: 73
# Length: 195

# %%
sequences = data["dssp8"]
amino_acid_counts = Counter("".join(sequences))
sorted_amino_acids = sorted(amino_acid_counts.items(), key=lambda x: x[1], reverse=True)
aa_df = pd.DataFrame(sorted_amino_acids, columns=["Amino Acid", "Count"])
plt.figure(figsize=(10, 5))
sns.barplot(x="Amino Acid", y="Count", data=aa_df, palette="viridis")
plt.xlabel("Amino Acid")
plt.ylabel("Frequency")
plt.title("Distribution of Amino Acids in Sequences")
plt.show()
# Out:
# C:\Users\tomas\AppData\Local\Temp\ipykernel_13848\1190696409.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Amino Acid", y="Count", data=aa_df, palette="viridis")

# %%
df = pd.read_csv("embeddings.csv")
print("Number of rows:", len(df))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv("embeddings.csv")
#       2 print("Number of rows:", len(df))
#
# File ~\miniconda3\envs\mol\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv("embeddings.csv")
print(df.head(0))

# %%
null_counts = df.isna().sum()
print(null_counts)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20, c21, c22, c23, c24, c25, c26, c27, c28, c29, c30, c31, c32, c33, c34, c35, c36, c37, c38, c39, c40, c41, c42, c43, c44, c45, c46, c47, c48, c49, c50, c51, c52, c53, c54, c55, c56, c57, c58, c59, c60, c61, c62, c63, c64, c65, c66, c67, c68, c69, c70, c71, c72, c73, c74, c75, c76, c77, c78, c79, c80, c81, c82, c83, c84, c85, c86, c87, c88, c89, c90, c91, c92, c93, c94, c95, c96, c97, c98, c99, c100, ...]
# Index: []
#
# [0 rows x 1026 columns]
